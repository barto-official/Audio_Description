# %%
# !pip install -qq nltk rouge transformers

# %%
import transformers
import torch
from typing import Optional, Tuple, Union
from transformers.modeling_outputs import Seq2SeqLMOutput
from transformers.generation.logits_process import WhisperTimeStampLogitsProcessor
from transformers.models.whisper.tokenization_whisper import TASK_IDS, TO_LANGUAGE_CODE


class WhisperForAudioCaptioning(transformers.WhisperForConditionalGeneration):

    def forward(
        self,
        input_features: Optional[torch.FloatTensor] = None,
        attention_mask: Optional[torch.LongTensor] = None,
        decoder_input_ids: Optional[torch.LongTensor] = None,
        decoder_attention_mask: Optional[torch.LongTensor] = None,
        head_mask: Optional[torch.Tensor] = None,
        decoder_head_mask: Optional[torch.Tensor] = None,
        cross_attn_head_mask: Optional[torch.Tensor] = None,
        encoder_outputs: Optional[Tuple[Tuple[torch.FloatTensor]]] = None,
        past_key_values: Optional[Tuple[Tuple[torch.FloatTensor]]] = None,
        decoder_inputs_embeds: Optional[Tuple[torch.FloatTensor]] = None,
        labels: Optional[torch.LongTensor] = None,
        use_cache: Optional[bool] = None,
        output_attentions: Optional[bool] = None,
        output_hidden_states: Optional[bool] = None,
        return_dict: Optional[bool] = None,
        forced_ac_decoder_ids: Optional[torch.LongTensor] = None, # added to be ignored when passed from trainer
    ) -> Union[Tuple[torch.Tensor], Seq2SeqLMOutput]:
        return super().forward(
            input_features=input_features,
            attention_mask=attention_mask,
            decoder_input_ids=decoder_input_ids,
            decoder_attention_mask=decoder_attention_mask,
            head_mask=head_mask,
            decoder_head_mask=decoder_head_mask,
            cross_attn_head_mask=cross_attn_head_mask,
            encoder_outputs=encoder_outputs,
            past_key_values=past_key_values,
            decoder_inputs_embeds=decoder_inputs_embeds,
            labels=labels,
            use_cache=use_cache,
            output_attentions=output_attentions,
            output_hidden_states=output_hidden_states,
            return_dict=return_dict,
        )

    # copy-pasted and adapted from transformers.WhisperForConditionalGeneration.generate
    def generate(
        self,
        inputs: Optional[torch.Tensor] = None,
        forced_ac_decoder_ids: Optional[torch.Tensor] = None,
        generation_config=None,
        logits_processor=None,
        stopping_criteria=None,
        prefix_allowed_tokens_fn=None,
        synced_gpus=False,
        return_timestamps=True,
        task="transcribe",
        language="english",
        **kwargs,
    ):
        if generation_config is None:
            generation_config = self.generation_config

        if return_timestamps is not None:
            if not hasattr(generation_config, "no_timestamps_token_id"):
                raise ValueError(
                    "You are trying to return timestamps, but the generation config is not properly set."
                    "Make sure to initialize the generation config with the correct attributes that are needed such as `no_timestamps_token_id`."
                    "For more details on how to generate the approtiate config, refer to https://github.com/huggingface/transformers/issues/21878#issuecomment-1451902363"
                )

            generation_config.return_timestamps = return_timestamps
        else:
            generation_config.return_timestamps = False

        if language is not None:
            generation_config.language = language
        if task is not None:
            generation_config.task = task

        forced_decoder_ids = []
        if task is not None or language is not None:
            if hasattr(generation_config, "language"):
                if generation_config.language in generation_config.lang_to_id.keys():
                    language_token = generation_config.language
                elif generation_config.language in TO_LANGUAGE_CODE.keys():
                    language_token = f"<|{TO_LANGUAGE_CODE[generation_config.language]}|>"
                else:
                    raise ValueError(
                        f"Unsupported language: {language}. Language should be one of:"
                        f" {list(TO_LANGUAGE_CODE.keys()) if generation_config.language in TO_LANGUAGE_CODE.keys() else list(TO_LANGUAGE_CODE.values())}."
                    )
                forced_decoder_ids.append((1, generation_config.lang_to_id[language_token]))
            else:
                forced_decoder_ids.append((1, None))  # automatically detect the language

            if hasattr(generation_config, "task"):
                if generation_config.task in TASK_IDS:
                    forced_decoder_ids.append((2, generation_config.task_to_id[generation_config.task]))
                else:
                    raise ValueError(
                        f"The `{generation_config.task}`task is not supported. The task should be one of `{TASK_IDS}`"
                    )
            else:
                forced_decoder_ids.append((2, generation_config.task_to_id["transcribe"]))  # defaults to transcribe
            if hasattr(generation_config, "no_timestamps_token_id") and not generation_config.return_timestamps:
                idx = forced_decoder_ids[-1][0] + 1 if forced_decoder_ids else 1
                forced_decoder_ids.append((idx, generation_config.no_timestamps_token_id))

        # Legacy code for backward compatibility
        elif hasattr(self.config, "forced_decoder_ids") and self.config.forced_decoder_ids is not None:
            forced_decoder_ids = self.config.forced_decoder_ids
        elif (
            hasattr(self.generation_config, "forced_decoder_ids")
            and self.generation_config.forced_decoder_ids is not None
        ):
            forced_decoder_ids = self.generation_config.forced_decoder_ids

        if generation_config.return_timestamps:
            logits_processor = [WhisperTimeStampLogitsProcessor(generation_config)]

        decoder_input_ids = None

        if len(forced_decoder_ids) > 0:
            # get the token sequence coded in forced_decoder_ids
            forced_decoder_ids.sort()
            if min(forced_decoder_ids)[0] != 0:
                forced_decoder_ids = [(0, self.config.decoder_start_token_id)] + forced_decoder_ids

            position_indices, decoder_input_ids = zip(*forced_decoder_ids)
            assert tuple(position_indices) == tuple(range(len(position_indices))), "forced_decoder_ids is not a (continuous) prefix, we can't handle that"

            device = self.get_decoder().device

            if forced_ac_decoder_ids is None:
                forced_ac_decoder_ids = torch.tensor([[]], device=device, dtype=torch.long)

            # enrich every sample's forced_ac_decoder_ids with Whisper's forced_decoder_ids
            batch_size = forced_ac_decoder_ids.shape[0]
            fluff_len = len(decoder_input_ids)
            decoder_input_ids = torch.tensor(decoder_input_ids, device=device, dtype=torch.long)
            decoder_input_ids = decoder_input_ids.expand((batch_size, fluff_len))
            decoder_input_ids = torch.cat([decoder_input_ids, forced_ac_decoder_ids], dim=1)

            generation_config.forced_decoder_ids = forced_decoder_ids

        return super(transformers.WhisperPreTrainedModel, self).generate(
            inputs,
            generation_config,
            logits_processor,
            stopping_criteria,
            prefix_allowed_tokens_fn,
            synced_gpus,
            decoder_input_ids=decoder_input_ids,
            **kwargs,
        )

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.translate.bleu_score import sentence_bleu
from rouge import Rouge
from nltk.translate.meteor_score import meteor_score
from nltk.translate.bleu_score import SmoothingFunction
from nltk import word_tokenize

def preprocess_caption(caption):
    """Remove punctuation and convert to lowercase."""
    return ''.join([c.lower() for c in caption if c.isalpha() or c.isspace()])

def compute_metrics(reference_captions, generated_caption):
    metrics = {}

    # Preprocess and tokenize captions
    generated_caption = preprocess_caption(generated_caption)
    reference_captions = [preprocess_caption(ref) for ref in reference_captions]
    gen_words = word_tokenize(generated_caption)
    ref_words = [word_tokenize(ref) for ref in reference_captions]

    # Apply smoothing for BLEU scores
    chencherry = SmoothingFunction()

    # Compute BLEU scores with smoothing
    for i in range(1, 5):
        weights = [1/i] * i
        metrics[f'BLEU{i}'] = sentence_bleu(ref_words, gen_words, weights=weights, smoothing_function=chencherry.method1)

    # Compute ROUGE-L
    rouge = Rouge()
    scores = rouge.get_scores(' '.join(gen_words), ' '.join([' '.join(ref) for ref in ref_words]))
    metrics['ROUGEL'] = scores[0]['rouge-l']['f']

    # Compute METEOR (using tokenized hypothesis)
    metrics['METEOR'] = meteor_score(ref_words, gen_words)

    return metrics

# %%
# Load the pre-trained Whisper Medium Audio Captioning model
checkpoint = "MU-NLPC/whisper-small-audio-captioning"
hugging_face_token = ""

model = WhisperForAudioCaptioning.from_pretrained(checkpoint,token=hugging_face_token)
tokenizer = transformers.WhisperTokenizer.from_pretrained(checkpoint, language="en", task="caption", predict_timestamps=True)
feature_extractor = transformers.WhisperFeatureExtractor.from_pretrained(checkpoint)
# Out:
# config.json:   0%|          | 0.00/2.25k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/967M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/utils/hub.py:374: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# generation_config.json:   0%|          | 0.00/3.62k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/800 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# preprocessor_config.json:   0%|          | 0.00/339 [00:00<?, ?B/s]

# %%
import librosa

def generate_caption(audio_file):
    audio, sampling_rate = librosa.load(audio_file, sr=feature_extractor.sampling_rate)
    features = feature_extractor(audio, sampling_rate=sampling_rate, return_tensors="pt").input_features
    # Prepare the caption style
    style_prefix = "clotho > caption: "
    #style_prefix = " "
    style_prefix_tokens = tokenizer("", text_target=style_prefix, return_tensors="pt", add_special_tokens=False).labels

    model.eval()
    outputs = model.generate(
        inputs=features.to(model.device),
        forced_ac_decoder_ids=style_prefix_tokens,
        max_length=300,
        num_beams=4,
        return_timestamps=True,
        early_stopping=True
    )
    caption = tokenizer.decode(outputs[0], decode_with_timestamps=True, skip_special_tokens=True)

    return caption

# %%
import pandas as pd
import soundfile as sf
from transformers import WhisperFeatureExtractor

# Load the metadata and captions
metadata_path = 'drive/MyDrive/metrics/clotho_metadata_evaluation.csv'
captions_path = 'drive/MyDrive/metrics/clotho_captions_evaluation.csv'

clotho_metadata = pd.read_csv(metadata_path, sep=',')
clotho_captions = pd.read_csv(captions_path)

# Merge the metadata with captions
# This step assumes that the file names match exactly in both datasets.
# If not, you might need additional preprocessing to match the file names.
combined_data = clotho_metadata.merge(clotho_captions, on='file_name')

# Create the metrics dictionary for the overall mean
cumulative_metrics = {
    'BLEU1': 0, 'BLEU2': 0, 'BLEU3': 0, 'BLEU4': 0,
    'ROUGEL': 0, 'METEOR': 0
}
num_files = 0

# Function to load and preprocess audio
def preprocess_audio(file_name):
    audio, sample_rate = sf.read(file_name)
    return feature_extractor(audio, sampling_rate=16000)

# Iterate over the dataset and generate captions
for index, row in combined_data.iterrows():
    audio_file = row['file_name']
    # Assuming audio files are in a directory named 'audio_files'
    audio_path = f'drive/MyDrive/metrics/evaluation/{audio_file}'

    # Preprocess the audio
    input_features = preprocess_audio(audio_path)

    # Generate caption
    generated_caption = generate_caption(audio_path)

    # Extract reference captions
    reference_captions = [row[f'caption_{i}'] for i in range(1, 6)]

    # Compute metrics
    metrics = compute_metrics(reference_captions, generated_caption)

    # Aggregate the metrics
    for key in cumulative_metrics:
        cumulative_metrics[key] += metrics[key]
    num_files += 1

    # Print or store the metrics for analysis
    print(f"Testing on file {num_files}")

# Calculate the mean metrics
mean_metrics = {key: val / num_files for key, val in cumulative_metrics.items()}

# Print the mean metrics
print("Mean Metrics for all audio files:", mean_metrics)
# Out:
# Testing on file 1
# Testing on file 2
# Testing on file 3
# Testing on file 4
# Testing on file 5
# Testing on file 6
# Testing on file 7
# Testing on file 8
# Testing on file 9
# Testing on file 10
# Testing on file 11
# Testing on file 12
# Testing on file 13
# Testing on file 14
# Testing on file 15
# Testing on file 16
# Testing on file 17
# Testing on file 18
# Testing on file 19
# Testing on file 20
# Testing on file 21
# Testing on file 22
# Testing on file 23
# Testing on file 24
# Testing on file 25
# Testing on file 26
# Testing on file 27
# Testing on file 28
# Testing on file 29
# Testing on file 30
# Testing on file 31
# Testing on file 32
# Testing on file 33
# Testing on file 34
# Testing on file 35
# Testing on file 36
# Testing on file 37
# Testing on file 38
# Testing on file 39
# Testing on file 40
# Testing on file 41
# Testing on file 42
# Testing on file 43
# Testing on file 44
# Testing on file 45
# Testing on file 46
# Testing on file 47
# Testing on file 48
# Testing on file 49
# Testing on file 50
# Testing on file 51
# Testing on file 52
# Testing on file 53
# Testing on file 54
# Testing on file 55
# Testing on file 56
# Testing on file 57
# Testing on file 58
# Testing on file 59
# Testing on file 60
# Testing on file 61
# Testing on file 62
# Testing on file 63
# Testing on file 64
# Testing on file 65
# Testing on file 66
# Testing on file 67
# Testing on file 68
# Testing on file 69
# Testing on file 70
# Testing on file 71
# Testing on file 72
# Testing on file 73
# Testing on file 74
# Testing on file 75
# Testing on file 76
# Testing on file 77
# Testing on file 78
# Testing on file 79
# Testing on file 80
# Testing on file 81
# Testing on file 82
# Testing on file 83
# Testing on file 84
# Testing on file 85
# Testing on file 86
# Testing on file 87
# Testing on file 88
# Testing on file 89
# Testing on file 90
# Testing on file 91
# Testing on file 92
# Testing on file 93
# Testing on file 94
# Testing on file 95
# Testing on file 96
# Testing on file 97
# Testing on file 98
# Testing on file 99
# Testing on file 100
# Testing on file 101
# Testing on file 102
# Testing on file 103
# Testing on file 104
# Testing on file 105
# Testing on file 106
# Testing on file 107
# Testing on file 108
# Testing on file 109
# Testing on file 110
# Testing on file 111
# Testing on file 112
# Testing on file 113
# Testing on file 114
# Testing on file 115
# Testing on file 116
# Testing on file 117
# Testing on file 118
# Testing on file 119
# Testing on file 120
# Testing on file 121
# Testing on file 122
# Testing on file 123
# Testing on file 124
# Testing on file 125
# Testing on file 126
# Testing on file 127
# Testing on file 128
# Testing on file 129
# Testing on file 130
# Testing on file 131
# Testing on file 132
# Testing on file 133
# Testing on file 134
# Testing on file 135
# Testing on file 136
# Testing on file 137
# Testing on file 138
# Testing on file 139
# Testing on file 140
# Testing on file 141
# Testing on file 142
# Testing on file 143
# Testing on file 144
# Testing on file 145
# Testing on file 146
# Testing on file 147
# Testing on file 148
# Testing on file 149
# Testing on file 150
# Testing on file 151
# Testing on file 152
# Testing on file 153
# Testing on file 154
# Testing on file 155
# Testing on file 156
# Testing on file 157
# Testing on file 158
# Testing on file 159
# Testing on file 160
# Testing on file 161
# Testing on file 162
# Testing on file 163
# Testing on file 164
# Testing on file 165
# Testing on file 166
# Testing on file 167
# Testing on file 168
# Testing on file 169
# Testing on file 170
# Testing on file 171
# Testing on file 172
# Testing on file 173
# Testing on file 174
# Testing on file 175
# Testing on file 176
# Testing on file 177
# Testing on file 178
# Testing on file 179
# Testing on file 180
# Testing on file 181
# Testing on file 182
# Testing on file 183
# Testing on file 184
# Testing on file 185
# Testing on file 186
# Testing on file 187
# Testing on file 188
# Testing on file 189
# Testing on file 190
# Testing on file 191
# Testing on file 192
# Testing on file 193
# Testing on file 194
# Testing on file 195
# Testing on file 196
# Testing on file 197
# Testing on file 198
# Testing on file 199
# Testing on file 200
# Testing on file 201
# Testing on file 202
# Testing on file 203
# Testing on file 204
# Testing on file 205
# Testing on file 206
# Testing on file 207
# Testing on file 208
# Testing on file 209
# Testing on file 210
# Testing on file 211
# Testing on file 212
# Testing on file 213
# Testing on file 214
# Testing on file 215
# Testing on file 216
# Testing on file 217
# Testing on file 218
# Testing on file 219
# Testing on file 220
# Testing on file 221
# Testing on file 222
# Testing on file 223
# Testing on file 224
# Testing on file 225
# Testing on file 226
# Testing on file 227
# Testing on file 228
# Testing on file 229
# Testing on file 230
# Testing on file 231
# Testing on file 232
# Testing on file 233
# Testing on file 234
# Testing on file 235
# Testing on file 236
# Testing on file 237
# Testing on file 238
# Testing on file 239
# Testing on file 240
# Testing on file 241
# Testing on file 242
# Testing on file 243
# Testing on file 244
# Testing on file 245
# Testing on file 246
# Testing on file 247
# Testing on file 248
# Testing on file 249
# Testing on file 250
# Testing on file 251
# Testing on file 252
# Testing on file 253
# Testing on file 254
# Testing on file 255
# Testing on file 256
# Testing on file 257
# Testing on file 258
# Testing on file 259
# Testing on file 260
# Testing on file 261
# Testing on file 262
# Testing on file 263
# Testing on file 264
# Testing on file 265
# Testing on file 266
# Testing on file 267
# Testing on file 268
# Testing on file 269
# Testing on file 270
# Testing on file 271
# Testing on file 272
# Testing on file 273
# Testing on file 274
# Testing on file 275
# Testing on file 276
# Testing on file 277
# Testing on file 278
# Testing on file 279
# Testing on file 280
# Testing on file 281
# Testing on file 282
# Testing on file 283
# Testing on file 284
# Testing on file 285
# Testing on file 286
# Testing on file 287
# Testing on file 288
# Testing on file 289
# Testing on file 290
# Testing on file 291
# Testing on file 292
# Testing on file 293
# Testing on file 294
# Testing on file 295
# Testing on file 296
# Testing on file 297
# Testing on file 298
# Testing on file 299
# Testing on file 300
# Testing on file 301
# Testing on file 302
# Testing on file 303
# Testing on file 304
# Testing on file 305
# Testing on file 306
# Testing on file 307
# Testing on file 308
# Testing on file 309
# Testing on file 310
# Testing on file 311
# Testing on file 312
# Testing on file 313
# Testing on file 314
# Testing on file 315
# Testing on file 316
# Testing on file 317
# Testing on file 318
# Testing on file 319
# Testing on file 320
# Testing on file 321
# Testing on file 322
# Testing on file 323
# Testing on file 324
# Testing on file 325
# Testing on file 326
# Testing on file 327
# Testing on file 328
# Testing on file 329
# Testing on file 330
# Testing on file 331
# Testing on file 332
# Testing on file 333
# Testing on file 334
# Testing on file 335
# Testing on file 336
# Testing on file 337
# Testing on file 338
# Testing on file 339
# Testing on file 340
# Testing on file 341
# Testing on file 342
# Testing on file 343
# Testing on file 344
# Testing on file 345
# Testing on file 346
# Testing on file 347
# Testing on file 348
# Testing on file 349
# Testing on file 350
# Testing on file 351
# Testing on file 352
# Testing on file 353
# Testing on file 354
# Testing on file 355
# Testing on file 356
# Testing on file 357
# Testing on file 358
# Testing on file 359
# Testing on file 360
# Testing on file 361
# Testing on file 362
# Testing on file 363
# Testing on file 364
# Testing on file 365
# Testing on file 366
# Testing on file 367
# Testing on file 368
# Testing on file 369
# Testing on file 370
# Testing on file 371
# Testing on file 372
# Testing on file 373
# Testing on file 374
# Testing on file 375
# Testing on file 376
# Testing on file 377
# Testing on file 378
# Testing on file 379
# Testing on file 380
# Testing on file 381
# Testing on file 382
# Testing on file 383
# Testing on file 384
# Testing on file 385
# Testing on file 386
# Testing on file 387
# Testing on file 388
# Testing on file 389
# Testing on file 390
# Testing on file 391
# Testing on file 392
# Testing on file 393
# Testing on file 394
# Testing on file 395
# Testing on file 396
# Testing on file 397
# Testing on file 398
# Testing on file 399
# Testing on file 400
# Testing on file 401
# Testing on file 402
# Testing on file 403
# Testing on file 404
# Testing on file 405
# Testing on file 406
# Testing on file 407
# Testing on file 408
# Testing on file 409
# Testing on file 410
# Testing on file 411
# Testing on file 412
# Testing on file 413
# Testing on file 414
# Testing on file 415
# Testing on file 416
# Testing on file 417
# Testing on file 418
# Testing on file 419
# Testing on file 420
# Testing on file 421
# Testing on file 422
# Testing on file 423
# Testing on file 424
# Testing on file 425
# Testing on file 426
# Testing on file 427
# Testing on file 428
# Testing on file 429
# Testing on file 430
# Testing on file 431
# Testing on file 432
# Testing on file 433
# Testing on file 434
# Testing on file 435
# Testing on file 436
# Testing on file 437
# Testing on file 438
# Testing on file 439
# Testing on file 440
# Testing on file 441
# Testing on file 442
# Testing on file 443
# Testing on file 444
# Testing on file 445
# Testing on file 446
# Testing on file 447
# Testing on file 448
# Testing on file 449
# Testing on file 450
# Testing on file 451
# Testing on file 452
# Testing on file 453
# Testing on file 454
# Testing on file 455
# Testing on file 456
# Testing on file 457
# Testing on file 458
# Testing on file 459
# Testing on file 460
# Testing on file 461
# Testing on file 462
# Testing on file 463
# Testing on file 464
# Testing on file 465
# Testing on file 466
# Testing on file 467
# Testing on file 468
# Testing on file 469
# Testing on file 470
# Testing on file 471
# Testing on file 472
# Testing on file 473
# Testing on file 474
# Testing on file 475
# Testing on file 476
# Testing on file 477
# Testing on file 478
# Testing on file 479
# Testing on file 480
# Testing on file 481
# Testing on file 482
# Testing on file 483
# Testing on file 484
# Testing on file 485
# Testing on file 486
# Testing on file 487
# Testing on file 488
# Testing on file 489
# Testing on file 490
# Testing on file 491
# Testing on file 492
# Testing on file 493
# Testing on file 494
# Testing on file 495
# Testing on file 496
# Testing on file 497
# Testing on file 498
# Testing on file 499
# Testing on file 500
# Testing on file 501
# Testing on file 502
# Testing on file 503
# Testing on file 504
# Testing on file 505
# Testing on file 506
# Testing on file 507
# Testing on file 508
# Testing on file 509
# Testing on file 510
# Testing on file 511
# Testing on file 512
# Testing on file 513
# Testing on file 514
# Testing on file 515
# Testing on file 516
# Testing on file 517
# Testing on file 518
# Testing on file 519
# Testing on file 520
# Testing on file 521
# Testing on file 522
# Testing on file 523
# Testing on file 524
# Testing on file 525
# Testing on file 526
# Testing on file 527
# Testing on file 528
# Testing on file 529
# Testing on file 530
# Testing on file 531
# Testing on file 532
# Testing on file 533
# Testing on file 534
# Testing on file 535
# Testing on file 536
# Testing on file 537
# Testing on file 538
# Testing on file 539
# Testing on file 540
# Testing on file 541
# Testing on file 542
# Testing on file 543
# Testing on file 544
# Testing on file 545
# Testing on file 546
# Testing on file 547
# Testing on file 548
# Testing on file 549
# Testing on file 550
# Testing on file 551
# Testing on file 552
# Testing on file 553
# Testing on file 554
# Testing on file 555
# Testing on file 556
# Testing on file 557
# Testing on file 558
# Testing on file 559
# Testing on file 560
# Testing on file 561
# Testing on file 562
# Testing on file 563
# Testing on file 564
# Testing on file 565
# Testing on file 566
# Testing on file 567
# Testing on file 568
# Testing on file 569
# Testing on file 570
# Testing on file 571
# Testing on file 572
# Testing on file 573
# Testing on file 574
# Testing on file 575
# Testing on file 576
# Testing on file 577
# Testing on file 578
# Testing on file 579
# Testing on file 580
# Testing on file 581
# Testing on file 582
# Testing on file 583
# Testing on file 584
# Testing on file 585
# Testing on file 586
# Testing on file 587
# Testing on file 588
# Testing on file 589
# Testing on file 590
# Testing on file 591
# Testing on file 592
# Testing on file 593
# Testing on file 594
# Testing on file 595
# Testing on file 596
# Testing on file 597
# Testing on file 598
# Testing on file 599
# Testing on file 600
# Testing on file 601
# Testing on file 602
# Testing on file 603
# Testing on file 604
# Testing on file 605
# Testing on file 606
# Testing on file 607
# Testing on file 608
# Testing on file 609
# Testing on file 610
# Testing on file 611
# Testing on file 612
# Testing on file 613
# Testing on file 614
# Testing on file 615
# Testing on file 616
# Testing on file 617
# Testing on file 618
# Testing on file 619
# Testing on file 620
# Testing on file 621
# Testing on file 622
# Testing on file 623
# Testing on file 624
# Testing on file 625
# Testing on file 626
# Testing on file 627
# Testing on file 628
# Testing on file 629
# Testing on file 630
# Testing on file 631
# Testing on file 632
# Testing on file 633
# Testing on file 634
# Testing on file 635
# Testing on file 636
# Testing on file 637
# Testing on file 638
# Testing on file 639
# Testing on file 640
# Testing on file 641
# Testing on file 642
# Testing on file 643
# Testing on file 644
# Testing on file 645
# Testing on file 646
# Testing on file 647
# Testing on file 648
# Testing on file 649
# Testing on file 650
# Testing on file 651
# Testing on file 652
# Testing on file 653
# Testing on file 654
# Testing on file 655
# Testing on file 656
# Testing on file 657
# Testing on file 658
# Testing on file 659
# Testing on file 660
# Testing on file 661
# Testing on file 662
# Testing on file 663
# Testing on file 664
# Testing on file 665
# Testing on file 666
# Testing on file 667
# Testing on file 668
# Testing on file 669
# Testing on file 670
# Testing on file 671
# Testing on file 672
# Testing on file 673
# Testing on file 674
# Testing on file 675
# Testing on file 676
# Testing on file 677
# Testing on file 678
# Testing on file 679
# Testing on file 680
# Testing on file 681
# Testing on file 682
# Testing on file 683
# Testing on file 684
# Testing on file 685
# Testing on file 686
# Testing on file 687
# Testing on file 688
# Testing on file 689
# Testing on file 690
# Testing on file 691
# Testing on file 692
# Testing on file 693
# Testing on file 694
# Testing on file 695
# Testing on file 696
# Testing on file 697
# Testing on file 698
# Testing on file 699
# Testing on file 700
# Testing on file 701
# Testing on file 702
# Testing on file 703
# Testing on file 704
# Testing on file 705
# Testing on file 706
# Testing on file 707
# Testing on file 708
# Testing on file 709
# Testing on file 710
# Testing on file 711
# Testing on file 712
# Testing on file 713
# Testing on file 714
# Testing on file 715
# Testing on file 716
# Testing on file 717
# Testing on file 718
# Testing on file 719
# Testing on file 720
# Testing on file 721
# Testing on file 722
# Testing on file 723
# Testing on file 724
# Testing on file 725
# Testing on file 726
# Testing on file 727
# Testing on file 728
# Testing on file 729
# Testing on file 730
# Testing on file 731
# Testing on file 732
# Testing on file 733
# Testing on file 734
# Testing on file 735
# Testing on file 736
# Testing on file 737
# Testing on file 738
# Testing on file 739
# Testing on file 740
# Testing on file 741
# Testing on file 742
# Testing on file 743
# Testing on file 744
# Testing on file 745
# Testing on file 746
# Testing on file 747
# Testing on file 748
# Testing on file 749
# Testing on file 750
# Testing on file 751
# Testing on file 752
# Testing on file 753
# Testing on file 754
# Testing on file 755
# Testing on file 756
# Testing on file 757
# Testing on file 758
# Testing on file 759
# Testing on file 760
# Testing on file 761
# Testing on file 762
# Testing on file 763
# Testing on file 764
# Testing on file 765
# Testing on file 766
# Testing on file 767
# Testing on file 768
# Testing on file 769
# Testing on file 770
# Testing on file 771
# Testing on file 772
# Testing on file 773
# Testing on file 774
# Testing on file 775
# Testing on file 776
# Testing on file 777
# Testing on file 778
# Testing on file 779
# Testing on file 780
# Testing on file 781
# Testing on file 782
# Testing on file 783
# Testing on file 784
# Testing on file 785
# Testing on file 786
# Testing on file 787
# Testing on file 788
# Testing on file 789
# Testing on file 790
# Testing on file 791
# Testing on file 792
# Testing on file 793
# Testing on file 794
# Testing on file 795
# Testing on file 796
# Testing on file 797
# Testing on file 798
# Testing on file 799
# Testing on file 800
# Testing on file 801
# Testing on file 802
# Testing on file 803
# Testing on file 804
# Testing on file 805
# Testing on file 806
# Testing on file 807
# Testing on file 808
# Testing on file 809
# Testing on file 810
# Testing on file 811
# Testing on file 812
# Testing on file 813
# Testing on file 814
# Testing on file 815
# Testing on file 816
# Testing on file 817
# Testing on file 818
# Testing on file 819
# Testing on file 820
# Testing on file 821
# Testing on file 822
# Testing on file 823
# Testing on file 824
# Testing on file 825
# Testing on file 826
# Testing on file 827
# Testing on file 828
# Testing on file 829
# Testing on file 830
# Testing on file 831
# Testing on file 832
# Testing on file 833
# Testing on file 834
# Testing on file 835
# Testing on file 836
# Testing on file 837
# Testing on file 838
# Testing on file 839
# Testing on file 840
# Testing on file 841
# Testing on file 842
# Testing on file 843
# Testing on file 844
# Testing on file 845
# Testing on file 846
# Testing on file 847
# Testing on file 848
# Testing on file 849
# Testing on file 850
# Testing on file 851
# Testing on file 852
# Testing on file 853
# Testing on file 854
# Testing on file 855
# Testing on file 856
# Testing on file 857
# Testing on file 858
# Testing on file 859
# Testing on file 860
# Testing on file 861
# Testing on file 862
# Testing on file 863
# Testing on file 864
# Testing on file 865
# Testing on file 866
# Testing on file 867
# Testing on file 868
# Testing on file 869
# Testing on file 870
# Testing on file 871
# Testing on file 872
# Testing on file 873
# Testing on file 874
# Testing on file 875
# Testing on file 876
# Testing on file 877
# Testing on file 878
# Testing on file 879
# Testing on file 880
# Testing on file 881
# Testing on file 882
# Testing on file 883
# Testing on file 884
# Testing on file 885
# Testing on file 886
# Testing on file 887
# Testing on file 888
# Testing on file 889
# Testing on file 890
# Testing on file 891
# Testing on file 892
# Testing on file 893
# Testing on file 894
# Testing on file 895
# Testing on file 896
# Testing on file 897
# Testing on file 898
# Testing on file 899
# Testing on file 900
# Testing on file 901
# Testing on file 902
# Testing on file 903
# Testing on file 904
# Testing on file 905
# Testing on file 906
# Testing on file 907
# Testing on file 908
# Testing on file 909
# Testing on file 910
# Testing on file 911
# Testing on file 912
# Testing on file 913
# Testing on file 914
# Testing on file 915
# Testing on file 916
# Testing on file 917
# Testing on file 918
# Testing on file 919
# Testing on file 920
# Testing on file 921
# Testing on file 922
# Testing on file 923
# Testing on file 924
# Testing on file 925
# Testing on file 926
# Testing on file 927
# Testing on file 928
# Testing on file 929
# Testing on file 930
# Testing on file 931
# Testing on file 932
# Testing on file 933
# Testing on file 934
# Testing on file 935
# Testing on file 936
# Testing on file 937
# Testing on file 938
# Testing on file 939
# Testing on file 940
# Testing on file 941
# Testing on file 942
# Testing on file 943
# Testing on file 944
# Testing on file 945
# Testing on file 946
# Testing on file 947
# Testing on file 948
# Testing on file 949
# Testing on file 950
# Testing on file 951
# Testing on file 952
# Testing on file 953
# Testing on file 954
# Testing on file 955
# Testing on file 956
# Testing on file 957
# Testing on file 958
# Testing on file 959
# Testing on file 960
# Testing on file 961
# Testing on file 962
# Testing on file 963
# Testing on file 964
# Testing on file 965
# Testing on file 966
# Testing on file 967
# Testing on file 968
# Testing on file 969
# Testing on file 970
# Testing on file 971
# Testing on file 972
# Testing on file 973
# Testing on file 974
# Testing on file 975
# Testing on file 976
# Testing on file 977
# Testing on file 978
# Testing on file 979
# Testing on file 980
# Testing on file 981
# Testing on file 982
# Testing on file 983
# Testing on file 984
# Testing on file 985
# Testing on file 986
# Testing on file 987
# Testing on file 988
# Testing on file 989
# Testing on file 990
# Testing on file 991
# Testing on file 992
# Testing on file 993
# Testing on file 994
# Testing on file 995
# Testing on file 996
# Testing on file 997
# Testing on file 998
# Testing on file 999
# Testing on file 1000
# Testing on file 1001
# Testing on file 1002
# Testing on file 1003
# Testing on file 1004
# Testing on file 1005
# Testing on file 1006
# Testing on file 1007
# Testing on file 1008
# Testing on file 1009
# Testing on file 1010
# Testing on file 1011
# Testing on file 1012
# Testing on file 1013
# Testing on file 1014
# Testing on file 1015
# Testing on file 1016
# Testing on file 1017
# Testing on file 1018
# Testing on file 1019
# Testing on file 1020
# Testing on file 1021
# Testing on file 1022
# Testing on file 1023
# Testing on file 1024
# Testing on file 1025
# Testing on file 1026
# Testing on file 1027
# Testing on file 1028
# Testing on file 1029
# Testing on file 1030
# Testing on file 1031
# Testing on file 1032
# Testing on file 1033
# Testing on file 1034
# Testing on file 1035
# Testing on file 1036
# Testing on file 1037
# Testing on file 1038
# Testing on file 1039
# Testing on file 1040
# Testing on file 1041
# Testing on file 1042
# Testing on file 1043
# Testing on file 1044
# Testing on file 1045
# Mean Metrics for all audio files: {'BLEU1': 0.4584411310372508, 'BLEU2': 0.27402289682937764, 'BLEU3': 0.17190684915144655, 'BLEU4': 0.11035115921217158, 'ROUGEL': 0.21604395949452163, 'METEOR': 0.3418029720541008}
